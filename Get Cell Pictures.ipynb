# %%
# %matplotlib inline

# %%
import classifier_utils as utils

# %%
import matplotlib.pyplot as plt

# %%
categories = [
    'epithelial',
    'fibroblast',
    'inflammatory',
    'others'
]
train, test = utils.get_dataset_divided_per_image(categories)
# Out:
# Dropped 1559 patches because too close to image border
# Dropped 523 patches because too close to image border

# %%
plt.imshow(test['patches'][600])
plt.xticks([])
plt.yticks([])
plt.savefig('cell0')

# %%
plt.imshow(test['patches'][601])
plt.xticks([])
plt.yticks([])
plt.savefig('cell1')

# %%
(all_imgs, all_centres, all_labels) = utils.get_dataset(100, categories)

# %%
i = 8
utils.draw(all_imgs[i], all_centres[i], all_labels[i], categories, figsize=(12, 8))
plt.savefig('full_img')
